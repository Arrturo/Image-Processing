# %%
from Image import *


photo = Image('D://Dokumenty//Code//Python//Introduction-to-Computer-Graphics//data//lena.jpg')
photo1 = Image('D://Dokumenty//Code//Python//Introduction-to-Computer-Graphics//data//lena.jpg')

# %%
gray = photo1.to_gray()

# %%
hist = photo.histogram()
hist.plot()

# %%
hist1 = gray.histogram()
hist1.plot()

# %%
from Image import *


photo = Image('D://Dokumenty//Code//Python//Introduction-to-Computer-Graphics//data//lena.jpg')
photo1 = Image('D://Dokumenty//Code//Python//Introduction-to-Computer-Graphics//data//madelyn.jpg')

# %%
photo.compare_to(photo1, 0)
# Out:
# 266756.546875

# %%
from Image import *


photo = Image('D://Dokumenty//Code//Python//Introduction-to-Computer-Graphics//data//lena.jpg')
photo1 = Image('D://Dokumenty//Code//Python//Introduction-to-Computer-Graphics//data//madelyn.jpg')

# %%
photo.compare_to(photo1, 1)
# Out:
# 516.484798300008
