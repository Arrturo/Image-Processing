# %%
from BaseImage import BaseImage
import numpy as np
photo = BaseImage('D://Dokumenty//Code//Python//Introduction-to-Computer-Graphics//lab2//lena.jpg')
photo2 = BaseImage('D://Dokumenty//Code//Python//Introduction-to-Computer-Graphics//lab2//lena.jpg')
photo3 = BaseImage('D://Dokumenty//Code//Python//Introduction-to-Computer-Graphics//lab2//lena.jpg')
# print(photo.data)

# %%
photo.data
# Out:
# array([[[226, 136, 127],
#         [225, 135, 126],
#         [225, 135, 126],
#         ...,
#         [235, 151, 123],
#         [216, 135, 106],
#         [191, 110,  81]],
#
#        [[226, 136, 127],
#         [226, 136, 127],
#         [226, 136, 127],
#         ...,
#         [228, 144, 120],
#         [208, 126, 102],
#         [184, 102,  78]],
#
#        [[227, 137, 128],
#         [227, 137, 128],
#         [226, 136, 125],
#         ...,
#         [230, 144, 127],
#         [211, 128, 110],
#         [189, 106,  88]],
#
#        ...,
#
#        [[ 89,  19,  55],
#         [ 91,  21,  57],
#         [ 92,  25,  60],
#         ...,
#         [173,  68,  82],
#         [176,  68,  83],
#         [176,  68,  81]],
#
#        [[ 90,  20,  56],
#         [ 92,  22,  58],
#         [ 93,  26,  61],
#         ...,
#         [176,  71,  85],
#         [179,  71,  84],
#         [183,  73,  84]],
#
#        [[ 91,  21,  57],
#         [ 93,  23,  59],
#         [ 94,  27,  62],
#         ...,
#         [176,  70,  82],
#         [179,  71,  84],
#         [183,  73,  84]]], dtype=uint8)

# %%
photo.show_img()

# %%
HSV = photo.to_hsv()
HSI = photo2.to_hsi()
HSL = photo3.to_hsl()

# %%
RGB = HSV.to_rgb()

# %%
RGB2 = HSI.to_rgb()

# %%
RGB3 = HSL.to_rgb()

# %%
RGB.show_img()

# %%
RGB2.show_img()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
RGB3.show_img()

# %%
HSL.data
# Out:
# array([[[226, 134, 127],
#         [225, 133, 126],
#         [225, 133, 126],
#         ...,
#         [235, 148, 122],
#         [216, 133, 105],
#         [191, 108,  81]],
#
#        [[226, 134, 127],
#         [226, 134, 127],
#         [226, 134, 127],
#         ...,
#         [228, 141, 120],
#         [207, 124, 101],
#         [183, 100,  77]],
#
#        [[227, 135, 128],
#         [227, 135, 128],
#         [226, 134, 125],
#         ...,
#         [230, 142, 126],
#         [211, 126, 110],
#         [189, 104,  88]],
#
#        ...,
#
#        [[ 89,  18,  55],
#         [ 91,  20,  57],
#         [ 92,  24,  60],
#         ...,
#         [173,  68,  80],
#         [176,  68,  81],
#         [176,  68,  79]],
#
#        [[ 90,  20,  56],
#         [ 92,  22,  58],
#         [ 93,  26,  61],
#         ...,
#         [176,  71,  83],
#         [179,  71,  82],
#         [183,  73,  82]],
#
#        [[ 91,  20,  57],
#         [ 93,  22,  59],
#         [ 94,  26,  62],
#         ...,
#         [176,  70,  80],
#         [179,  71,  82],
#         [183,  73,  82]]], dtype=uint16)

# %%
HSI.data
# Out:
# array([[[234, 127, 127],
#         [234, 126, 125],
#         [234, 126, 125],
#         ...,
#         [263, 123, 123],
#         [245, 106, 106],
#         [219,  81,  81]],
#
#        [[234, 127, 127],
#         [234, 127, 127],
#         [234, 127, 127],
#         ...,
#         [252, 120, 120],
#         [231, 102, 102],
#         [208,  78,  77]],
#
#        [[236, 128, 128],
#         [236, 128, 128],
#         [237, 125, 125],
#         ...,
#         [247, 127, 126],
#         [228, 110, 110],
#         [206,  88,  88]],
#
#        ...,
#
#        [[124,  19,  19],
#         [126,  21,  21],
#         [126,  25,  25],
#         ...,
#         [187,  67,  68],
#         [190,  68,  68],
#         [188,  68,  68]],
#
#        [[126,  20,  20],
#         [127,  22,  22],
#         [127,  26,  26],
#         ...,
#         [190,  71,  71],
#         [191,  71,  71],
#         [194,  73,  72]],
#
#        [[126,  21,  21],
#         [129,  23,  23],
#         [128,  27,  27],
#         ...,
#         [187,  70,  70],
#         [191,  71,  71],
#         [194,  73,  72]]], dtype=uint16)

# %%
HSV.data
# Out:
# array([[[226, 129, 127],
#         [225, 128, 126],
#         [225, 128, 126],
#         ...,
#         [235, 125, 122],
#         [216, 108, 106],
#         [191,  83,  80]],
#
#        [[226, 129, 127],
#         [226, 129, 127],
#         [226, 129, 127],
#         ...,
#         [228, 122, 120],
#         [208, 104, 101],
#         [184,  80,  77]],
#
#        [[227, 130, 127],
#         [227, 130, 127],
#         [226, 127, 125],
#         ...,
#         [230, 129, 126],
#         [211, 112, 110],
#         [189,  89,  88]],
#
#        ...,
#
#        [[ 89,  18,  20],
#         [ 91,  21,  22],
#         [ 92,  24,  26],
#         ...,
#         [173,  67,  69],
#         [176,  67,  69],
#         [176,  67,  69]],
#
#        [[ 90,  20,  21],
#         [ 92,  22,  23],
#         [ 93,  26,  27],
#         ...,
#         [176,  71,  72],
#         [179,  71,  72],
#         [183,  72,  74]],
#
#        [[ 91,  21,  22],
#         [ 93,  23,  24],
#         [ 94,  26,  28],
#         ...,
#         [176,  70,  71],
#         [179,  71,  72],
#         [183,  72,  74]]], dtype=uint16)

# %%
RGB.data
# Out:
# array([[[226, 129, 127],
#         [225, 128, 126],
#         [225, 128, 126],
#         ...,
#         [235, 125, 122],
#         [216, 108, 106],
#         [191,  83,  80]],
#
#        [[226, 129, 127],
#         [226, 129, 127],
#         [226, 129, 127],
#         ...,
#         [228, 122, 120],
#         [208, 104, 101],
#         [184,  80,  77]],
#
#        [[227, 130, 127],
#         [227, 130, 127],
#         [226, 127, 125],
#         ...,
#         [230, 129, 126],
#         [211, 112, 110],
#         [189,  89,  88]],
#
#        ...,
#
#        [[ 89,  18,  20],
#         [ 91,  21,  22],
#         [ 92,  24,  26],
#         ...,
#         [173,  67,  69],
#         [176,  67,  69],
#         [176,  67,  69]],
#
#        [[ 90,  20,  21],
#         [ 92,  22,  23],
#         [ 93,  26,  27],
#         ...,
#         [176,  71,  72],
#         [179,  71,  72],
#         [183,  72,  74]],
#
#        [[ 91,  21,  22],
#         [ 93,  23,  24],
#         [ 94,  26,  28],
#         ...,
#         [176,  70,  71],
#         [179,  71,  72],
#         [183,  72,  74]]], dtype=uint16)

# %%
RGB2.data
# Out:
# array([[[234, 127, 127],
#         [234, 126, 125],
#         [234, 126, 125],
#         ...,
#         [263, 123, 123],
#         [245, 106, 106],
#         [219,  81,  81]],
#
#        [[234, 127, 127],
#         [234, 127, 127],
#         [234, 127, 127],
#         ...,
#         [252, 120, 120],
#         [231, 102, 102],
#         [208,  78,  77]],
#
#        [[236, 128, 128],
#         [236, 128, 128],
#         [237, 125, 125],
#         ...,
#         [247, 127, 126],
#         [228, 110, 110],
#         [206,  88,  88]],
#
#        ...,
#
#        [[124,  19,  19],
#         [126,  21,  21],
#         [126,  25,  25],
#         ...,
#         [187,  67,  68],
#         [190,  68,  68],
#         [188,  68,  68]],
#
#        [[126,  20,  20],
#         [127,  22,  22],
#         [127,  26,  26],
#         ...,
#         [190,  71,  71],
#         [191,  71,  71],
#         [194,  73,  72]],
#
#        [[126,  21,  21],
#         [129,  23,  23],
#         [128,  27,  27],
#         ...,
#         [187,  70,  70],
#         [191,  71,  71],
#         [194,  73,  72]]], dtype=uint16)

# %%
RGB3.data
# Out:
# array([[[226, 134, 127],
#         [225, 133, 126],
#         [225, 133, 126],
#         ...,
#         [235, 148, 122],
#         [216, 133, 105],
#         [191, 108,  81]],
#
#        [[226, 134, 127],
#         [226, 134, 127],
#         [226, 134, 127],
#         ...,
#         [228, 141, 120],
#         [207, 124, 101],
#         [183, 100,  77]],
#
#        [[227, 135, 128],
#         [227, 135, 128],
#         [226, 134, 125],
#         ...,
#         [230, 142, 126],
#         [211, 126, 110],
#         [189, 104,  88]],
#
#        ...,
#
#        [[ 89,  18,  55],
#         [ 91,  20,  57],
#         [ 92,  24,  60],
#         ...,
#         [173,  68,  80],
#         [176,  68,  81],
#         [176,  68,  79]],
#
#        [[ 90,  20,  56],
#         [ 92,  22,  58],
#         [ 93,  26,  61],
#         ...,
#         [176,  71,  83],
#         [179,  71,  82],
#         [183,  73,  82]],
#
#        [[ 91,  20,  57],
#         [ 93,  22,  59],
#         [ 94,  26,  62],
#         ...,
#         [176,  70,  80],
#         [179,  71,  82],
#         [183,  73,  82]]], dtype=uint16)
