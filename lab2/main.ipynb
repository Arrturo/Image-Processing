# %%
from BaseImage import BaseImage
photo = BaseImage(
    'D://Dokumenty//Code//Python//Introduction-to-Computer-Graphics//lab2//lena.jpg')
print(photo.data)
# Out:
# [[[226 136 127]
#   [225 135 126]
#   [225 135 126]
#   ...
#   [235 151 123]
#   [216 135 106]
#   [191 110  81]]
#
#  [[226 136 127]
#   [226 136 127]
#   [226 136 127]
#   ...
#   [228 144 120]
#   [208 126 102]
#   [184 102  78]]
#
#  [[227 137 128]
#   [227 137 128]
#   [226 136 125]
#   ...
#   [230 144 127]
#   [211 128 110]
#   [189 106  88]]
#
#  ...
#
#  [[ 89  19  55]
#   [ 91  21  57]
#   [ 92  25  60]
#   ...
#   [173  68  82]
#   [176  68  83]
#   [176  68  81]]
#
#  [[ 90  20  56]
#   [ 92  22  58]
#   [ 93  26  61]
#   ...
#   [176  71  85]
#   [179  71  84]
#   [183  73  84]]
#
#  [[ 91  21  57]
#   [ 93  23  59]
#   [ 94  27  62]
#   ...
#   [176  70  82]
#   [179  71  84]
#   [183  73  84]]]

# %%
photo.show_img()
# photo.save_img('D://Dokumenty//Code//Python//Introduction-to-Computer-Graphics//lab2//copy.jpg')

# %%
print(photo.get_layer(1))
photo.get_layer(2)
# Out:
# [[136 135 135 ... 151 135 110]
#  [136 136 136 ... 144 126 102]
#  [137 137 136 ... 144 128 106]
#  ...
#  [ 19  21  25 ...  68  68  68]
#  [ 20  22  26 ...  71  71  73]
#  [ 21  23  27 ...  70  71  73]]
# array([[127, 126, 126, ..., 123, 106,  81],
#        [127, 127, 127, ..., 120, 102,  78],
#        [128, 128, 125, ..., 127, 110,  88],
#        ...,
#        [ 55,  57,  60, ...,  82,  83,  81],
#        [ 56,  58,  61, ...,  85,  84,  84],
#        [ 57,  59,  62, ...,  82,  84,  84]], dtype=uint8)

# %%
photo.to_hsv()
# Out:
# array([[[1.24177495e+00, 4.38053097e-01, 8.86274510e-01],
#         [1.23919007e+00, 4.40000000e-01, 8.82352941e-01],
#         [1.23919007e+00, 4.40000000e-01, 8.82352941e-01],
#         ...,
#         [1.24294848e+00, 4.76595745e-01, 9.21568627e-01],
#         [1.21593413e+00, 5.09259259e-01, 8.47058824e-01],
#         [1.15061093e+00, 5.75916230e-01, 7.49019608e-01]],
#
#        [[1.24177495e+00, 4.38053097e-01, 8.86274510e-01],
#         [1.24177495e+00, 4.38053097e-01, 8.86274510e-01],
#         [1.24177495e+00, 4.38053097e-01, 8.86274510e-01],
#         ...,
#         [1.23869995e+00, 4.73684211e-01, 8.94117647e-01],
#         [1.20530662e+00, 5.09615385e-01, 8.15686275e-01],
#         [1.13798387e+00, 5.76086957e-01, 7.21568627e-01]],
#
#        [[1.24329713e+00, 4.36123348e-01, 8.90196078e-01],
#         [1.24329713e+00, 4.36123348e-01, 8.90196078e-01],
#         [1.23704744e+00, 4.46902655e-01, 8.86274510e-01],
#         ...,
# ...

# %%
photo.show_img()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
