# %%
from BaseImage import BaseImage


photo = BaseImage('D://Dokumenty//Code//Python//Introduction-to-Computer-Graphics//data//lena.jpg')
photo1 = BaseImage('D://Dokumenty//Code//Python//Introduction-to-Computer-Graphics//data//lena.jpg')
photo2 = BaseImage('D://Dokumenty//Code//Python//Introduction-to-Computer-Graphics//data//lena.jpg')

# %%
# photo.data

# %%
photo.show_img()

# %%
HSV = photo.to_hsv()
HSI = photo1.to_hsi()
HSL = photo2.to_hsl()

# %%
# HSV.data

# %%
# HSI.data

# %%
# HSL.data

# %%
RGB = HSV.to_rgb()

# %%
RGB2 = HSI.to_rgb()

# %%
RGB3 = HSL.to_rgb()

# %%
RGB.show_img()

# %%
RGB2.show_img()

# %%
RGB3.show_img()

# %%
# RGB.data

# %%
# RGB2.data

# %%
# RGB3.data
