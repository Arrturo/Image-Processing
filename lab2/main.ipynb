# %%
from BaseImage import BaseImage
from matplotlib.colors import rgb_to_hsv, hsv_to_rgb
from matplotlib.pyplot import imshow
import numpy as np
photo = BaseImage('D://Dokumenty//Code//Python//Introduction-to-Computer-Graphics//lab2//lena.jpg')
photo2 = BaseImage('D://Dokumenty//Code//Python//Introduction-to-Computer-Graphics//lab2//lena.jpg')
photo3 = BaseImage('D://Dokumenty//Code//Python//Introduction-to-Computer-Graphics//lab2//lena.jpg')
# print(photo.data)

# %%
photo.data
# Out:
# array([[[226, 136, 127],
#         [225, 135, 126],
#         [225, 135, 126],
#         ...,
#         [235, 151, 123],
#         [216, 135, 106],
#         [191, 110,  81]],
#
#        [[226, 136, 127],
#         [226, 136, 127],
#         [226, 136, 127],
#         ...,
#         [228, 144, 120],
#         [208, 126, 102],
#         [184, 102,  78]],
#
#        [[227, 137, 128],
#         [227, 137, 128],
#         [226, 136, 125],
#         ...,
#         [230, 144, 127],
#         [211, 128, 110],
#         [189, 106,  88]],
#
#        ...,
#
#        [[ 89,  19,  55],
#         [ 91,  21,  57],
#         [ 92,  25,  60],
#         ...,
#         [173,  68,  82],
#         [176,  68,  83],
#         [176,  68,  81]],
#
#        [[ 90,  20,  56],
#         [ 92,  22,  58],
#         [ 93,  26,  61],
#         ...,
#         [176,  71,  85],
#         [179,  71,  84],
#         [183,  73,  84]],
#
#        [[ 91,  21,  57],
#         [ 93,  23,  59],
#         [ 94,  27,  62],
# ...

# %%
photo.show_img()

# %%
HSV = photo.to_hsv()
HSI = photo2.to_hsi()
HSL = photo3.to_hsl()
# Out:
# d:\Dokumenty\Code\Python\Introduction-to-Computer-Graphics\lab2\BaseImage.py:103: RuntimeWarning: invalid value encountered in arccos
#   H[i][j] = (2 * np.pi) - np.arccos(H[i, j])

# %%
HSV.data
# Out:
# array([[[1.24177495e+00, 4.38053097e-01, 8.86274510e-01],
#         [1.23919007e+00, 4.40000000e-01, 8.82352941e-01],
#         [1.23919007e+00, 4.40000000e-01, 8.82352941e-01],
#         ...,
#         [1.24294848e+00, 4.76595745e-01, 9.21568627e-01],
#         [1.21593413e+00, 5.09259259e-01, 8.47058824e-01],
#         [1.15061093e+00, 5.75916230e-01, 7.49019608e-01]],
#
#        [[1.24177495e+00, 4.38053097e-01, 8.86274510e-01],
#         [1.24177495e+00, 4.38053097e-01, 8.86274510e-01],
#         [1.24177495e+00, 4.38053097e-01, 8.86274510e-01],
#         ...,
#         [1.23869995e+00, 4.73684211e-01, 8.94117647e-01],
#         [1.20530662e+00, 5.09615385e-01, 8.15686275e-01],
#         [1.13798387e+00, 5.76086957e-01, 7.21568627e-01]],
#
#        [[1.24329713e+00, 4.36123348e-01, 8.90196078e-01],
#         [1.24329713e+00, 4.36123348e-01, 8.90196078e-01],
#         [1.23704744e+00, 4.46902655e-01, 8.86274510e-01],
#         ...,
# ...

# %%
HSI.data
# Out:
# array([[[  1.55340122,   0.22085887, 163.        ],
#         [  1.55340122,   0.22222224, 162.        ],
#         [  1.55340122,   0.22222224, 162.        ],
#         ...,
#         [  1.55385316,   0.27504911, 169.66666667],
#         [  1.55391616,   0.30415756, 152.33333333],
#         [  1.55391616,   0.36387435, 127.33333333]],
#
#        [[  1.55340122,   0.22085887, 163.        ],
#         [  1.55340122,   0.22085887, 163.        ],
#         [  1.55340122,   0.22085887, 163.        ],
#         ...,
#         [  1.55373743,   0.26829267, 164.        ],
#         [  1.55375383,   0.29816514, 145.33333333],
#         [  1.55375383,   0.35714285, 121.33333333]],
#
#        [[  1.55340122,   0.21951222, 164.        ],
#         [  1.55340122,   0.21951222, 164.        ],
#         [  1.55342835,   0.22997946, 162.33333333],
#         ...,
#         [  1.55355021,   0.23952097, 167.        ],
#         [  1.55358746,   0.26503342, 149.66666667],
# ...

# %%
HSL.data
# Out:
# array([[[ 1.24177495e+00, -1.02061856e+00,  1.90196078e-01],
#         [ 1.23919007e+00, -1.04210526e+00,  1.86274510e-01],
#         [ 1.23919007e+00, -1.04210526e+00,  1.86274510e-01],
#         ...,
#         [ 1.24294848e+00, -1.09803922e+00,  2.00000000e-01],
#         [ 1.21593413e+00, -1.66666667e+00,  1.29411765e-01],
#         [ 1.15061093e+00, -6.87500000e+00,  3.13725490e-02]],
#
#        [[ 1.24177495e+00, -1.02061856e+00,  1.90196078e-01],
#         [ 1.24177495e+00, -1.02061856e+00,  1.90196078e-01],
#         [ 1.24177495e+00, -1.02061856e+00,  1.90196078e-01],
#         ...,
#         [ 1.23869995e+00, -1.17391304e+00,  1.80392157e-01],
#         [ 1.20530662e+00, -1.96296296e+00,  1.05882353e-01],
#         [ 1.13798387e+00, -1.76666667e+01,  1.17647059e-02]],
#
#        [[ 1.24329713e+00, -1.00000000e+00,  1.94117647e-01],
#         [ 1.24329713e+00, -1.00000000e+00,  1.94117647e-01],
#         [ 1.23704744e+00, -1.06315789e+00,  1.86274510e-01],
#         ...,
# ...

# %%
RGB = HSV.to_rgb()

# %%
RGB2 = HSI.to_rgb()

# %%
RGB3 = HSL.to_rgb()

# %%
RGB.data
# Out:
# array([[[226, 129, 127],
#         [225, 128, 126],
#         [225, 128, 126],
#         ...,
#         [235, 125, 123],
#         [216, 108, 105],
#         [191,  83,  80]],
#
#        [[226, 129, 127],
#         [226, 129, 127],
#         [226, 129, 127],
#         ...,
#         [228, 122, 120],
#         [208, 104, 102],
#         [184,  80,  78]],
#
#        [[227, 130, 128],
#         [227, 130, 128],
#         [226, 127, 125],
#         ...,
#         [230, 129, 127],
#         [211, 112, 110],
#         [189,  89,  88]],
#
#        ...,
#
#        [[ 89,  18,  20],
#         [ 91,  21,  22],
#         [ 92,  25,  26],
#         ...,
#         [173,  68,  69],
#         [176,  68,  69],
#         [176,  68,  69]],
#
#        [[ 90,  20,  21],
#         [ 92,  21,  23],
#         [ 93,  25,  27],
#         ...,
#         [176,  70,  72],
#         [179,  71,  72],
#         [183,  73,  74]],
#
#        [[ 91,  21,  22],
#         [ 93,  23,  24],
#         [ 94,  27,  28],
# ...

# %%
RGB2.data
# Out:
# array([[[234, 127, 127],
#         [234, 125, 125],
#         [234, 125, 125],
#         ...,
#         [262, 123, 123],
#         [245, 105, 105],
#         [220,  80,  80]],
#
#        [[234, 127, 127],
#         [234, 127, 127],
#         [234, 127, 127],
#         ...,
#         [251, 120, 120],
#         [232, 101, 101],
#         [207,  78,  78]],
#
#        [[236, 127, 127],
#         [236, 127, 127],
#         [236, 125, 125],
#         ...,
#         [247, 126, 126],
#         [229, 109, 109],
#         [207,  87,  87]],
#
#        ...,
#
#        [[125,  18,  18],
#         [126,  21,  21],
#         [127,  24,  24],
#         ...,
#         [186,  68,  68],
#         [191,  67,  67],
#         [189,  67,  67]],
#
#        [[125,  20,  20],
#         [127,  22,  22],
#         [127,  26,  26],
#         ...,
#         [190,  70,  70],
#         [191,  71,  71],
#         [193,  73,  73]],
#
#        [[126,  21,  21],
#         [129,  22,  22],
#         [128,  27,  27],
# ...

# %%
RGB3.data
# Out:
# array([[[65535, 65283,    98],
#         [65535, 65282,    97],
#         [65535, 65282,    97],
#         ...,
#         [65531, 65279,   107],
#         [65514, 65262,    88],
#         [65489, 65237,    63]],
#
#        [[65535, 65283,    98],
#         [65535, 65283,    98],
#         [65535, 65283,    98],
#         ...,
#         [65528, 65276,   100],
#         [65510, 65258,    80],
#         [65486, 65234,    56]],
#
#        [[    0, 65284,    99],
#         [    0, 65284,    99],
#         [65533, 65281,    97],
#         ...,
#         [65535, 65283,   102],
#         [65518, 65266,    82],
#         [65496, 65243,    60]],
#
#        ...,
#
#        [[   19,    89, 65439],
#         [   21,    91, 65441],
#         [   25,    92, 65439],
#         ...,
#         [   68,   173,    21],
#         [   68,   176,    27],
#         [   68,   176,    27]],
#
#        [[   20,    90, 65440],
#         [   22,    92, 65442],
#         [   26,    93, 65440],
#         ...,
# ...

# %%
RGB.show_img()

# %%
RGB2.show_img()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
RGB3.show_img()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
