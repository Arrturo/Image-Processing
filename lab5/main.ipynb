# %%
import sys
sys.path.append('../')
from Image import *


photo = Image('D://Dokumenty//Code//Python//Introduction-to-Computer-Graphics//data//lung.jpg', 4)
photo1 = Image('D://Dokumenty//Code//Python//Introduction-to-Computer-Graphics//data//lung.jpg', 4)
photo2 = Image('D://Dokumenty//Code//Python//Introduction-to-Computer-Graphics//data//lung.jpg', 4)

# %%
hist = photo.histogram()
hist.plot()

# %%
align1 = photo1.align_image()
hist1 = align1.histogram()
hist1.plot()

# %%
align2 = photo2.align_image(True)
hist2 = align2.histogram()
hist2.plot()

# %%
show_3img(photo, align1, align2)

# %%
photo = Image('D://Dokumenty//Code//Python//Introduction-to-Computer-Graphics//data//fundus.jpg')
photo1 = Image('D://Dokumenty//Code//Python//Introduction-to-Computer-Graphics//data//fundus.jpg')
photo2 = Image('D://Dokumenty//Code//Python//Introduction-to-Computer-Graphics//data//fundus.jpg')

# %%
hist = photo.histogram()
hist.plot()

# %%
align1 = photo1.align_image()
hist1 = align1.histogram()
hist1.plot()

# %%
align2 = photo2.align_image(True)
hist2 = align2.histogram()
hist2.plot()

# %%
show_3img(photo, align1, align2)

# %%
photo = Image('D://Dokumenty//Code//Python//Introduction-to-Computer-Graphics//data//lena.jpg')
photo1 = Image('D://Dokumenty//Code//Python//Introduction-to-Computer-Graphics//data//lena.jpg')
photo2 = Image('D://Dokumenty//Code//Python//Introduction-to-Computer-Graphics//data//lena.jpg')

# %%
hist = photo.histogram()
hist.plot()

# %%
align1 = photo1.align_image()
hist1 = align1.histogram()
hist1.plot()

# %%
align2 = photo2.align_image(True)
hist2 = align2.histogram()
hist2.plot()

# %%
show_3img(photo, align1, align2)

# %%
photo = Image('D://Dokumenty//Code//Python//Introduction-to-Computer-Graphics//data//lena.jpg')
photo1 = Image('D://Dokumenty//Code//Python//Introduction-to-Computer-Graphics//data//lena.jpg')
photo2 = Image('D://Dokumenty//Code//Python//Introduction-to-Computer-Graphics//data//lena.jpg')

# %%
gray = photo.to_gray()
gray1 = photo1.to_gray()
gray2 = photo2.to_gray()

# %%
hist = gray.histogram()
hist.plot()

# %%
align1 = gray1.align_image()
hist1 = align1.histogram()
hist1.plot()

# %%
align2 = gray2.align_image(True)
hist2 = align2.histogram()
hist2.plot()

# %%
show_3img(photo, align1, align2)
